# %% [markdown]
# # Performance Models and Impact with Compression of Job-Data with K-Medoids-Clustering

# %%
import sys
sys.path.insert(0, '..')
import collections

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error as MAPE
from IPython.display import display, HTML
from ipywidgets import IntProgress

from RuntimePrediction.Predict import Predictor as C3OPredictor
from RuntimePrediction.DefaultModels import (GradientBoosting as GB,
                                             ErnestModel as EM)
from RuntimePrediction.CustomModels import (BasicOptimisticModel as BOM,
                                            OptimisticGradientBoosting as OGB)
from sklearn_extra.cluster import KMedoids
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## Extract Runtime Data

# %%
kmeans_df = pd.read_csv('../data/kmeans.tsv')
sort_df = pd.read_csv('../data/sort.tsv')
grep_df = pd.read_csv('../data/grep.tsv')
sgd_df = pd.read_csv('../data/sgd.tsv')
pagerank_df = pd.read_csv('../data/pagerank.tsv')

# %% [markdown]
# ## 1. Compression: Filter and remove duplicate datapoints

# %%
kmeans_compression_0 = kmeans_df.shape[0]
sort_compression_0 = sort_df.shape[0]
grep_compression_0 = grep_df.shape[0]
sgd_compression_0 = sgd_df.shape[0]
pagerank_compression_0 = pagerank_df.shape[0]

kmeans_df.drop_duplicates(inplace=True)
sort_df.drop_duplicates(inplace=True)
grep_df.drop_duplicates(inplace=True)
sgd_df.drop_duplicates(inplace=True)
pagerank_df.drop_duplicates(inplace=True)

kmeans_df.to_csv('../data/reduced-kmeans_1.tsv', index=False)
sort_df.to_csv('../data/reduced-sort_1.tsv', index=False)
grep_df.to_csv('../data/reduced-grep_1.tsv', index=False)
sgd_df.to_csv('../data/reduced-sgd_1.tsv', index=False)
pagerank_df.to_csv('../data/reduced-pagerank_1.tsv', index=False)

kmeans_compression_1 = round(1 - (kmeans_df.shape[0])/kmeans_compression_0, 4)
sort_compression_1 = round(1 - (sort_df.shape[0])/sort_compression_0, 4)
grep_compression_1 = round(1 - (grep_df.shape[0])/grep_compression_0, 4)
sgd_compression_1 = round(1 - (sgd_df.shape[0])/sgd_compression_0, 4)
pagerank_compression_1 = round(1 - (pagerank_df.shape[0])/pagerank_compression_0, 4)

kmeans_dp = kmeans_df.shape[0]
sort_dp = sort_df.shape[0]
grep_dp = grep_df.shape[0]
sgd_dp = sgd_df.shape[0]
pagerank_dp = pagerank_df.shape[0]

print("KMeans: First Compression: " + str(kmeans_compression_1) + " Datapoints: " + str(kmeans_df.shape[0]))
print("Sort: First Compression: " + str(sort_compression_1) + " Datapoints: " + str(sort_df.shape[0]))
print("Grep: First Compression: " + str(grep_compression_1) + " Datapoints: " + str(grep_df.shape[0]))
print("Sgd: First Compression: " + str(sgd_compression_1) + " Datapoints: " + str(sgd_df.shape[0]))
print("Pagerank: First Compression: " + str(pagerank_compression_1) + " Datapoints: " + str(pagerank_df.shape[0]))
# Out:
# KMeans: First Compression: 0.2733 Datapoints: 654
# Sort: First Compression: 0.2873 Datapoints: 449
# Grep: First Compression: 0.358 Datapoints: 520
# Sgd: First Compression: 0.4578 Datapoints: 488
# Pagerank: First Compression: 0.1631 Datapoints: 1180

# %% [markdown]
# ## 2. K-MEDOIDS Clustering

# %%
# Ignore feature 'machine_type'
kmeans_machine_type_column= pd.read_csv('../data/reduced-kmeans_1.tsv', sep='\t', usecols=range(1,2))
sort_machine_type_column= pd.read_csv('../data/reduced-sort_1.tsv', sep='\t', usecols=range(1,2))
grep_machine_type_column= pd.read_csv('../data/reduced-grep_1.tsv', sep='\t', usecols=range(1,2))
sgd_machine_type_column= pd.read_csv('../data/reduced-sgd_1.tsv', sep='\t', usecols=range(1,2))
pagerank_machine_type_column= pd.read_csv('../data/reduced-pagerank_1.tsv', sep='\t', usecols=range(1,2))

kmeans_headers = [*pd.read_csv('../data/reduced-kmeans_1.tsv', sep='\t', nrows=1)]
reducedKmeans = pd.read_csv('../data/reduced-kmeans_1.tsv', sep='\t', usecols=[c for c in kmeans_headers if c != 'machine_type'])

sort_headers = [*pd.read_csv('../data/reduced-sort_1.tsv', sep='\t', nrows=1)]
reducedSort = pd.read_csv('../data/reduced-sort_1.tsv', sep='\t', usecols=[c for c in sort_headers if c != 'machine_type'])

grep_headers = [*pd.read_csv('../data/reduced-grep_1.tsv', sep='\t', nrows=1)]
reducedGrep = pd.read_csv('../data/reduced-grep_1.tsv', sep='\t', usecols=[c for c in grep_headers if c != 'machine_type'])

sgd_headers = [*pd.read_csv('../data/reduced-sgd_1.tsv', sep='\t', nrows=1)]
reducedSgd = pd.read_csv('../data/reduced-sgd_1.tsv', sep='\t', usecols=[c for c in sgd_headers if c != 'machine_type'])

pagerank_headers = [*pd.read_csv('../data/reduced-pagerank_1.tsv', sep='\t', nrows=1)]
reducedPagerank = pd.read_csv('../data/reduced-pagerank_1.tsv', sep='\t', usecols=[c for c in pagerank_headers if c != 'machine_type'])

# %%
# create Clusters with KMedoids // n_clusters => e.g. 200,150,100,45,35,25,15
km_kmeans = KMedoids(n_clusters=200, init='k-medoids++').fit(reducedKmeans)
km_sort = KMedoids(n_clusters=200, init='k-medoids++').fit(reducedSort)
km_grep = KMedoids(n_clusters=200, init='k-medoids++').fit(reducedGrep)
km_sgd = KMedoids(n_clusters=200, init='k-medoids++').fit(reducedSgd)
km_pagerank = KMedoids(n_clusters=200, init='k-medoids++').fit(reducedPagerank)

# calculate Silhoutte Score for optimal n_cluster
kmeans_score = silhouette_score(reducedKmeans, km_kmeans.labels_, metric='euclidean')
sort_score = silhouette_score(reducedSort, km_sort.labels_, metric='euclidean')
grep_score = silhouette_score(reducedGrep, km_grep.labels_, metric='euclidean')
sgd_score = silhouette_score(reducedSgd, km_sgd.labels_, metric='euclidean')
pagerank_score = silhouette_score(reducedPagerank, km_pagerank.labels_, metric='euclidean')

print('Silhouetter Score KMeans: %.3f' % kmeans_score)
print('Silhouetter Score Sort: %.3f' % sort_score)
print('Silhouetter Score Grep: %.3f' % grep_score)
print('Silhouetter Score Sgd: %.3f' % sgd_score)
print('Silhouetter Score Pagerank: %.3f' % pagerank_score)

# get Centroids of the current clusters
centralKmeans, _ = pairwise_distances_argmin_min(km_kmeans.cluster_centers_, reducedKmeans)
centralSort, _ = pairwise_distances_argmin_min(km_sort.cluster_centers_, reducedSort)
centralGrep, _ = pairwise_distances_argmin_min(km_grep.cluster_centers_, reducedGrep)
centralSgd, _ = pairwise_distances_argmin_min(km_sgd.cluster_centers_, reducedSgd)
centralPagerank, _ = pairwise_distances_argmin_min(km_pagerank.cluster_centers_, reducedPagerank)

# filter the centroid rows of current dataset and add feature machine_type back
kmeans_dataset = pd.read_csv("../data/reduced-kmeans_1.tsv")
sort_dataset = pd.read_csv("../data/reduced-sort_1.tsv")
grep_dataset = pd.read_csv("../data/reduced-grep_1.tsv")
sgd_dataset = pd.read_csv("../data/reduced-sgd_1.tsv")
pagerank_dataset = pd.read_csv("../data/reduced-pagerank_1.tsv")

kmeans_machine_type_column.join(kmeans_dataset)
kmeans_filter_centroids = kmeans_dataset.iloc[centralKmeans].sort_index(0, ascending=True)
kmeans_filter_centroids.to_csv('../data/kmedoids/reduced-kmeans_200.tsv', index=False)

sort_machine_type_column.join(sort_dataset)
sort_filter_centroids = sort_dataset.iloc[centralSort].sort_index(0, ascending=True)
sort_filter_centroids.to_csv('../data/kmedoids/reduced-sort_200.tsv', index=False)

grep_machine_type_column.join(grep_dataset)
grep_filter_centroids = grep_dataset.iloc[centralGrep].sort_index(0, ascending=True)
grep_filter_centroids.to_csv('../data/kmedoids/reduced-grep_200.tsv', index=False)

sgd_machine_type_column.join(sgd_dataset)
sgd_filter_centroids = sgd_dataset.iloc[centralSgd].sort_index(0, ascending=True)
sgd_filter_centroids.to_csv('../data/kmedoids/reduced-sgd_200.tsv', index=False)

pagerank_machine_type_column.join(pagerank_dataset)
pagerank_filter_centroids = pagerank_dataset.iloc[centralPagerank].sort_index(0, ascending=True)
pagerank_filter_centroids.to_csv('../data/kmedoids/reduced-pagerank_200.tsv', index=False)
# Out:
# Silhouetter Score KMeans: 0.961
# Silhouetter Score Sort: 0.631
# Silhouetter Score Grep: 0.958
# Silhouetter Score Sgd: 0.894
# Silhouetter Score Pagerank: 0.958

# %%
kmeans_compression_2 = pd.read_csv('../data/kmedoids/reduced-kmeans_200.tsv')
sort_compression_2 = pd.read_csv('../data/kmedoids/reduced-sort_200.tsv')
grep_compression_2 = pd.read_csv('../data/kmedoids/reduced-grep_200.tsv')
sgd_compression_2 = pd.read_csv('../data/kmedoids/reduced-sgd_200.tsv')
pagerank_compression_2 = pd.read_csv('../data/kmedoids/reduced-pagerank_200.tsv')

kmeans_compression_K = round(1 - (kmeans_compression_2.shape[0])/kmeans_compression_0, 4)
sort_compression_K = round(1 - (sort_compression_2.shape[0])/sort_compression_0, 4)
grep_compression_K = round(1 - (grep_compression_2.shape[0])/grep_compression_0, 4)
sgd_compression_K = round(1 - (sgd_compression_2.shape[0])/sgd_compression_0, 4)
pagerank_compression_K = round(1 - (pagerank_compression_2.shape[0])/pagerank_compression_0, 4)

print("KMeans: Compression: " + str(kmeans_compression_K) + " Datapoints: " + str(kmeans_compression_2.shape[0]))
print("Sort: Compression: " + str(sort_compression_K) + " Datapoints: " + str(sort_compression_2.shape[0]))
print("Grep: Compression: " + str(grep_compression_K) + " Datapoints: " + str(grep_compression_2.shape[0]))
print("Sgd: Compression: " + str(sgd_compression_K) + " Datapoints: " + str(sgd_compression_2.shape[0]))
print("Pagerank: Compression: " + str(pagerank_compression_K) + " Datapoints: " + str(pagerank_compression_2.shape[0]))
# Out:
# KMeans: Compression: 0.7778 Datapoints: 200
# Sort: Compression: 0.6825 Datapoints: 200
# Grep: Compression: 0.7531 Datapoints: 200
# Sgd: Compression: 0.7778 Datapoints: 200
# Pagerank: Compression: 0.8582 Datapoints: 200

# %% [markdown]
# ## Define Models

# %%
Model = collections.namedtuple('Model', ['name', 'predictor', 'kwargs'])

models = [
          Model('Ernest', EM, {}),
          Model('GBM', GB, {}), 
          
          Model('BOM', BOM, {}), 
          Model('OGB', OGB, {}), 
   
          Model('C3O', C3OPredictor, {}),
         ]

# %% [markdown]
# ## Extract Runtime Data

# %%
kmeans_df = pd.read_csv('../data/kmedoids/reduced-kmeans_200.tsv', sep='\t')
sort_df = pd.read_csv('../data/kmedoids/reduced-sort_200.tsv', sep='\t')
grep_df = pd.read_csv('../data/kmedoids/reduced-grep_200.tsv', sep='\t')
sgd_df = pd.read_csv('../data/kmedoids/reduced-sgd_200.tsv', sep='\t')
pagerank_df = pd.read_csv('../data/kmedoids/reduced-pagerank_200.tsv', sep='\t')

kmeans_dp = kmeans_df.shape[0]
sort_dp = sort_df.shape[0]
grep_dp = grep_df.shape[0]
sgd_dp = sgd_df.shape[0]
pagerank_dp = pagerank_df.shape[0]

print(kmeans_dp)
print(sort_dp)
print(grep_dp)
print(sgd_dp)
print(pagerank_dp)
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
Job = collections.namedtuple('Job', ['name', 'X', 'y'])

def get_training_data(df, features, filters):
    # Get medians
    g = df.groupby(by=['instance_count','machine_type']+features)
    df = pd.DataFrame(g.median().to_records())
    # Apply filters
    # e.g. only for one machine type each, the full c3o-experiments were conducted
    # No full cartesian product!
    for k, s, v in filters:
        if s == '==': df = df[df[k] == v]
        if s == '>' : df = df[df[k] >  v]
    X = df[['instance_count'] + features]
    y = (df[['gross_runtime']]).squeeze()
    return X, y

td = get_training_data
jobs = [
    Job('Sort',
        *(td(sort_df,
          ['data_size_MB'],
          [('machine_type', '==', 'c4.2xlarge'),
            ('line_length', '==', 100)] )) ),
    Job('Grep',
       *(td(grep_df,
           ['data_size_MB', 'p_occurrence'],
            [('machine_type', '==', 'm4.2xlarge')] )) ),
    Job('SGDLR',
        *(td(sgd_df,
            ['observations', 'features', 'iterations'],
            [('machine_type', '==', 'r4.2xlarge'),
             ('instance_count', '>', 2)] )) ),
   Job('K-Means',
        *(td(kmeans_df,
            ['observations', 'features', 'k'],
            [('machine_type', '==', 'r4.2xlarge'),
             ('instance_count', '>', 2)] )) ),
    Job('Page Rank',
        *(td(pagerank_df,
            ['links', 'pages', 'convergence_criterion'],
            [('machine_type', '==', 'r4.2xlarge')] )) ),
]

# %% [markdown]
# ## Train-Test Split Creations

# %%
def create_partial_training_data(job, splits):
    for _ in range(splits):
        yield train_test_split(job.X,job.y)

# %% [markdown]
# ### Calculating the Model Prediction Errors

# %%
def evaluate(model, X_train, X_test, y_train, y_test, error_metric):
    model_instance = model.predictor(**model.kwargs)
    model_instance.fit(X_train, y_train)
    y_pred = model_instance.predict(X_test)
    error = error_metric(y_test, y_pred)
    return error

# %%
def create_new_compression_evaluations(amount):
    with open('kmedoids_compression_results.csv', 'at') as f:
        for job in jobs:
            for split in create_partial_training_data(job, splits=amount):
                for model in models:
                    error = evaluate(model, *split, MAPE)
                    if job.name == 'K-Means':
                        f.write(f"{job.name},{model.name},{kmeans_dp},{error}\n")
                    if job.name == 'Sort':
                        f.write(f"{job.name},{model.name},{sort_dp},{error}\n")
                    if job.name == 'Grep':
                        f.write(f"{job.name},{model.name},{grep_dp},{error}\n")
                    if job.name == 'SGDLR':
                        f.write(f"{job.name},{model.name},{sgd_dp},{error}\n")
                    if job.name == 'Page Rank':
                        f.write(f"{job.name},{model.name},{pagerank_dp},{error}\n")

# %%
create_new_compression_evaluations(amount=200)

# %% [markdown]
# ### Display the Results

# %%
def read_results(job_name):
    try: results = pd.read_csv('compression_results_kmedoids.csv', header=None)
    except: return

    rres = [(job, model, ds, float(mape)) for job, model, ds, mape in results.values]
    df = pd.DataFrame(rres, columns = ('Job', 'Model', 'Compression', 'MAPE'))
    groups = df.groupby(by=['Job', 'Model', 'Compression'], as_index=False)
    df = groups.mean()
    # Filter info for just the job we are interested in
    jobdf = df[df['Job'] == job_name].set_index(['Model', 'Compression'])
    # Remove redundant info
    return jobdf.unstack()['MAPE']

def display_job_evaluation(job_name):
    
    try: displaydf = read_results(job_name)
    except: display(HTML(f"<h3>{job_name}</h3> None")); return 
    
    # Style the output to highlight the important information
    def highlight_row_min(row):
        return ['color: black' if cell == min(row) else 'color: dimgray' for cell in row]
    
    def highlight_min(data, color='aquamarine', bold=False):
        # highlight the minimum in a Series or DataFrame
        attr1 = f"background-color: {color}"
        attr2 = f"font-weight: {'bold' if bold else 'normal'}"
        if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
            is_min = data == data.min()
            return [attr1 if v else '' for v in is_min]
        else:  # from .apply(axis=None)
            is_min = data == data.min().min()
            return pd.DataFrame(np.where(is_min, attr2, ''),
                                index=data.index, columns=data.columns)
        
    table_html = displaydf.style.apply(highlight_row_min,axis=1) \
                                .apply(highlight_min, axis=0, color='aquamarine') \
                                .apply(highlight_min, axis=None, bold=True) \
                                .format("{:.2%}") \
                                ._repr_html_()
    
    display(HTML(f"<h3>{job_name}</h3>" + table_html ))

# %% [markdown]
# ### Performance of the C3O Predictor and its Constituent Models

# %%
for job in jobs:
    display_job_evaluation(job.name)
# Out:
# <h3>Sort</h3><style  type="text/css" >
#     #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col2 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col4 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col5 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col6 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col7 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col8 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col9 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col13 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow0_col18 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col2 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col4 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col5 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col6 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col7 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col8 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col9 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col10 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col11 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col12 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col13 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col14 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col15 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col16 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col17 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow1_col18 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col0 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col1 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col2 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col3 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col4 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col5 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col6 {
#             color:  black;
#             background-color:  aquamarine;
#             font-weight:  bold;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col7 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col8 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col9 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col13 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow2_col18 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow3_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1721714_2c34_11ec_a4ab_c4b3018b0b8erow3_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1
# <h3>Grep</h3><style  type="text/css" >
#     #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col2 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col4 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col5 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col6 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col7 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col8 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col9 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col13 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow0_col18 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col2 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col3 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col4 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col5 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col6 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col7 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col8 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col9 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col13 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col16 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow1_col18 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col0 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col1 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col2 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col4 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col5 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col6 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col7 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col8 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col9 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col13 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow2_col18 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow3_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow3_col1 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow3_col2 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow3_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1abf420_2c34_11ec_a4ab_c4b3018b0b8erow3_col4 {
#             color:  dimgray;
#             bac
# <h3>SGDLR</h3><style  type="text/css" >
#     #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col1 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col2 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col4 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col5 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col6 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col7 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col8 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col9 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col13 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow0_col18 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col2 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col3 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col4 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col5 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col6 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col7 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col8 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col9 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col13 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col17 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow1_col18 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col0 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col2 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col4 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col5 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col6 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col7 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col8 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col9 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col13 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow2_col18 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow3_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow3_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow3_col2 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow3_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e1ea2948_2c34_11ec_a4ab_c4b3018b0b8erow3_col4 {
#             colo
# <h3>K-Means</h3><style  type="text/css" >
#     #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col2 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col3 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col4 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col5 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col6 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col7 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col8 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col9 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col13 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow0_col18 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col2 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col4 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col5 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col6 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col7 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col8 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col9 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col10 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col11 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col13 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow1_col18 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col0 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col1 {
#             color:  black;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col2 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col4 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col5 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col6 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col7 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col8 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col9 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col13 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow2_col18 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow3_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow3_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow3_col2 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e224ca94_2c34_11ec_a4ab_c4b3018b0b8erow3_col3 {
#             color:  dimgray;
#             : ;
#             :
# <h3>Page Rank</h3><style  type="text/css" >
#     #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col0 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col2 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col3 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col4 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col5 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col6 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col7 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col8 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col9 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col13 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow0_col18 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col2 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col4 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col5 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col6 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col7 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col8 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col9 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col10 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col11 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col12 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col13 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col14 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col15 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col16 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col17 {
#             color:  dimgray;
#             background-color:  aquamarine;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow1_col18 {
#             color:  black;
#             background-color:  aquamarine;
#             font-weight:  bold;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col2 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col3 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col4 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col5 {
#             color:  black;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col6 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col7 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col8 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col9 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col10 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col11 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col12 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col13 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col14 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col15 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col16 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col17 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow2_col18 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow3_col0 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow3_col1 {
#             color:  dimgray;
#             : ;
#             : ;
#         }    #T_e25d9b4e_2c34_11ec_a4ab_c4b3018b0b8erow3_col2 {
#             color:  dimgray;
#             : ;

# %%
ff = 'DejaVu Sans'
ff = 'DejaVu Serif'
matplotlib.rc('font', family=ff)

model_names = list(map(lambda m:m.name, models))

colors = ['tab:blue', 'tab:green', 'red', 'tab:orange', 'black']

plt.figure(figsize=(12,8))
for i, job in enumerate(jobs):
    results = read_results(job.name)
    plt.subplot(3,3,i+1)
    plt.title(job.name, fontsize=17)
    for j, model_name in enumerate(model_names):
        y = results.loc[model_name][:]
        x =  results.loc[model_name].keys()
        line = plt.plot(x, y, '--' if model_name=='C3O' else '-', label=model_name, color=colors[j])
        
        plt.xlabel('Datenpunkte', fontsize=15)
        plt.ylabel('MAPE', fontsize=15)
        
        plt.ylim(0, .45)

plt.figlegend(model_names, fontsize=15, loc='upper right', ncol=5, bbox_to_anchor=[0.85, +.28], 
              bbox_transform=plt.gcf().transFigure)
plt.tight_layout()
plt.savefig('compression_kmedoids.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Display KMEANS vs. KMEDOIDS

# %%
for job in jobs:
    results = pd.read_csv('kmedoids_vs_compression_results.csv', header=None)
    rres = [(job, model, ds, float(mape)) for job, model, ds, mape in results.values]
    df = pd.DataFrame(rres, columns = ('Job', 'Model', 'Compression', 'MAPE'))
    groups = df.groupby(by=['Job', 'Model', 'Compression'], as_index=False)
    df = groups.mean()
    # Filter info for just the job we are interested in
    jobdf = df[df['Job'] == job.name].set_index(['Model', 'Compression'])

c3oResults = df[df['Model'] == 'C3O'].iloc[::-1]
with open('dbscan_vs_kmeans_vs_kmedoids.csv', 'at') as f:
    for i in range(5):
        f.write(f"{'C3O-KMEDOIDS'},{i},{c3oResults.iloc[i::5, :].mean().values[1]}\n")
        print(c3oResults.iloc[i::5, :].mean().values[1])
# Out:
# 0.036211353158150515
# 0.0352092553064755
# 0.0478940102786458
# 0.08562887274730754
# 0.09187317905605039

# %%
Model = collections.namedtuple('Model', ['name', 'predictor', 'kwargs'])

models = [
          Model('C3O-DBSCAN', C3OPredictor, {}),
          Model('C3O-KMEANS', C3OPredictor, {}),
         ]

def read_results_all_jobs():
    try: results = pd.read_csv('dbscan_vs_kmeans_vs_kmedoids.csv', header=None)
    except: return

    rres = [(model, ds, float(mape)) for model, ds, mape in results.values]
    df = pd.DataFrame(rres, columns = ('Model', 'Compression', 'MAPE'))
    groups = df.groupby(by=['Model', 'Compression'], as_index=False)
    df = groups.mean()
    # Filter info for just the job we are interested in
    jobdf = df.set_index(['Model', 'Compression'])
    # Remove redundant info
    return jobdf.unstack()['MAPE']

ff = 'DejaVu Sans'
ff = 'DejaVu Serif'
matplotlib.rc('font', family=ff)

model_names = list(map(lambda m:m.name, models))

colors = ['tab:blue', 'tab:green', 'red', 'tab:orange', 'black']

plt.figure(figsize=(8,8))
results = read_results_all_jobs()
plt.subplot(3,2,1)
#plt.title('KMEANS vs. DBSCAN vs. KMEDEOIDS', fontsize=17)
for j, model_name in enumerate(model_names):
    y = results.loc[model_name][:]
    x = [0,1,2,3,4]
    line = plt.plot(x, y, label=model_name, color=colors[j])
    
    plt.xlabel('Kompressionsschritte', fontsize=15)
    plt.ylabel('MAPE', fontsize=15)
        
    plt.ylim(0, .25)

plt.figlegend(model_names, fontsize=15, loc='center right', 
              bbox_transform=plt.gcf().transFigure)
plt.savefig('dbscan_vs_kmeans_vs_kmedoids.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## GET MAPE of all Jobs

# %%
dataPoints = [200,190,180,170,160,150,140,130,120,110,100,90,80,70,60,45,35,25,15]

for job in jobs:
    results = pd.read_csv('compression_results_kmedoids.csv', header=None)
    rres = [(job, model, ds, float(mape)) for job, model, ds, mape in results.values]
    df = pd.DataFrame(rres, columns = ('Job', 'Model', 'Compression', 'MAPE'))
    groups = df.groupby(by=['Job', 'Model', 'Compression'], as_index=False)
    df = groups.mean()
    # Filter info for just the job we are interested in
    jobdf = df[df['Job'] == job.name].set_index(['Model', 'Compression'])

c3oResults = df[df['Model'] == 'C3O'].iloc[::-1]
print(c3oResults)
with open('kmeans_vs_kmedoids.csv', 'at') as f:
    for i in range(19):
        f.write(f"{'C3O-KMEDOIDS'},{dataPoints[i]},{c3oResults.iloc[i::19, :].mean().values[1]}\n")
        #print(c3oResults.iloc[i::19, :].mean().values[1])
# Out:
#       Job Model  Compression      MAPE
# 417  Sort   C3O          200  0.062534
# 416  Sort   C3O          190  0.068261
# 415  Sort   C3O          180  0.066182
# 414  Sort   C3O          170  0.066050
# 413  Sort   C3O          160  0.069191
# ..    ...   ...          ...       ...
# 23   Grep   C3O           60  0.149741
# 22   Grep   C3O           45  0.100087
# 21   Grep   C3O           35  0.092315
# 20   Grep   C3O           25  0.130337
# 19   Grep   C3O           15  0.190553
#
# [95 rows x 4 columns]
