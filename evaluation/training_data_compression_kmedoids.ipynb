# %% [markdown]
# # Performance Models and Impact with Compression of Job-Data with K-Medoids-Clustering

# %%
import sys
sys.path.insert(0, '..')
import collections

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error as MAPE
from IPython.display import display, HTML
from ipywidgets import IntProgress

from RuntimePrediction.Predict import Predictor as C3OPredictor
from RuntimePrediction.DefaultModels import (GradientBoosting as GB,
                                             ErnestModel as EM)
from RuntimePrediction.CustomModels import (BasicOptimisticModel as BOM,
                                            OptimisticGradientBoosting as OGB)
from sklearn_extra.cluster import KMedoids
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## Extract Runtime Data

# %%
kmeans_df = pd.read_csv('../data/kmeans.tsv')
sort_df = pd.read_csv('../data/sort.tsv')
grep_df = pd.read_csv('../data/grep.tsv')
sgd_df = pd.read_csv('../data/sgd.tsv')
pagerank_df = pd.read_csv('../data/pagerank.tsv')

# %% [markdown]
# ## 1. Compression: Filter and remove duplicate datapoints

# %%
kmeans_compression_0 = kmeans_df.shape[0]
sort_compression_0 = sort_df.shape[0]
grep_compression_0 = grep_df.shape[0]
sgd_compression_0 = sgd_df.shape[0]
pagerank_compression_0 = pagerank_df.shape[0]

kmeans_df.drop_duplicates(inplace=True)
sort_df.drop_duplicates(inplace=True)
grep_df.drop_duplicates(inplace=True)
sgd_df.drop_duplicates(inplace=True)
pagerank_df.drop_duplicates(inplace=True)

kmeans_df.to_csv('../data/reduced-kmeans_1.tsv', index=False)
sort_df.to_csv('../data/reduced-sort_1.tsv', index=False)
grep_df.to_csv('../data/reduced-grep_1.tsv', index=False)
sgd_df.to_csv('../data/reduced-sgd_1.tsv', index=False)
pagerank_df.to_csv('../data/reduced-pagerank_1.tsv', index=False)

kmeans_compression_1 = round(1 - (kmeans_df.shape[0])/kmeans_compression_0, 4)
sort_compression_1 = round(1 - (sort_df.shape[0])/sort_compression_0, 4)
grep_compression_1 = round(1 - (grep_df.shape[0])/grep_compression_0, 4)
sgd_compression_1 = round(1 - (sgd_df.shape[0])/sgd_compression_0, 4)
pagerank_compression_1 = round(1 - (pagerank_df.shape[0])/pagerank_compression_0, 4)

kmeans_dp = kmeans_df.shape[0]
sort_dp = sort_df.shape[0]
grep_dp = grep_df.shape[0]
sgd_dp = sgd_df.shape[0]
pagerank_dp = pagerank_df.shape[0]

print("KMeans: First Compression: " + str(kmeans_compression_1) + " Datapoints: " + str(kmeans_df.shape[0]))
print("Sort: First Compression: " + str(sort_compression_1) + " Datapoints: " + str(sort_df.shape[0]))
print("Grep: First Compression: " + str(grep_compression_1) + " Datapoints: " + str(grep_df.shape[0]))
print("Sgd: First Compression: " + str(sgd_compression_1) + " Datapoints: " + str(sgd_df.shape[0]))
print("Pagerank: First Compression: " + str(pagerank_compression_1) + " Datapoints: " + str(pagerank_df.shape[0]))
# Out:
# KMeans: First Compression: 0.2733 Datapoints: 654
# Sort: First Compression: 0.2873 Datapoints: 449
# Grep: First Compression: 0.358 Datapoints: 520
# Sgd: First Compression: 0.4578 Datapoints: 488
# Pagerank: First Compression: 0.1631 Datapoints: 1180

# %% [markdown]
# ## 2. K-MEDOIDS Clustering

# %%
# Ignore feature 'machine_type'
kmeans_machine_type_column= pd.read_csv('../data/reduced-kmeans_1.tsv', sep='\t', usecols=range(1,2))
sort_machine_type_column= pd.read_csv('../data/reduced-sort_1.tsv', sep='\t', usecols=range(1,2))
grep_machine_type_column= pd.read_csv('../data/reduced-grep_1.tsv', sep='\t', usecols=range(1,2))
sgd_machine_type_column= pd.read_csv('../data/reduced-sgd_1.tsv', sep='\t', usecols=range(1,2))
pagerank_machine_type_column= pd.read_csv('../data/reduced-pagerank_1.tsv', sep='\t', usecols=range(1,2))

kmeans_headers = [*pd.read_csv('../data/reduced-kmeans_1.tsv', sep='\t', nrows=1)]
reducedKmeans = pd.read_csv('../data/reduced-kmeans_1.tsv', sep='\t', usecols=[c for c in kmeans_headers if c != 'machine_type'])

sort_headers = [*pd.read_csv('../data/reduced-sort_1.tsv', sep='\t', nrows=1)]
reducedSort = pd.read_csv('../data/reduced-sort_1.tsv', sep='\t', usecols=[c for c in sort_headers if c != 'machine_type'])

grep_headers = [*pd.read_csv('../data/reduced-grep_1.tsv', sep='\t', nrows=1)]
reducedGrep = pd.read_csv('../data/reduced-grep_1.tsv', sep='\t', usecols=[c for c in grep_headers if c != 'machine_type'])

sgd_headers = [*pd.read_csv('../data/reduced-sgd_1.tsv', sep='\t', nrows=1)]
reducedSgd = pd.read_csv('../data/reduced-sgd_1.tsv', sep='\t', usecols=[c for c in sgd_headers if c != 'machine_type'])

pagerank_headers = [*pd.read_csv('../data/reduced-pagerank_1.tsv', sep='\t', nrows=1)]
reducedPagerank = pd.read_csv('../data/reduced-pagerank_1.tsv', sep='\t', usecols=[c for c in pagerank_headers if c != 'machine_type'])

# %%
# create Clusters with KMedoids // n_clusters => e.g. 200,150,100,45,35,25,15
km_kmeans = KMedoids(n_clusters=200, init='k-medoids++').fit(reducedKmeans)
km_sort = KMedoids(n_clusters=200, init='k-medoids++').fit(reducedSort)
km_grep = KMedoids(n_clusters=200, init='k-medoids++').fit(reducedGrep)
km_sgd = KMedoids(n_clusters=200, init='k-medoids++').fit(reducedSgd)
km_pagerank = KMedoids(n_clusters=200, init='k-medoids++').fit(reducedPagerank)

# calculate Silhoutte Score for optimal n_cluster
kmeans_score = silhouette_score(reducedKmeans, km_kmeans.labels_, metric='euclidean')
sort_score = silhouette_score(reducedSort, km_sort.labels_, metric='euclidean')
grep_score = silhouette_score(reducedGrep, km_grep.labels_, metric='euclidean')
sgd_score = silhouette_score(reducedSgd, km_sgd.labels_, metric='euclidean')
pagerank_score = silhouette_score(reducedPagerank, km_pagerank.labels_, metric='euclidean')

print('Silhouetter Score KMeans: %.3f' % kmeans_score)
print('Silhouetter Score Sort: %.3f' % sort_score)
print('Silhouetter Score Grep: %.3f' % grep_score)
print('Silhouetter Score Sgd: %.3f' % sgd_score)
print('Silhouetter Score Pagerank: %.3f' % pagerank_score)

# get Centroids of the current clusters
centralKmeans, _ = pairwise_distances_argmin_min(km_kmeans.cluster_centers_, reducedKmeans)
centralSort, _ = pairwise_distances_argmin_min(km_sort.cluster_centers_, reducedSort)
centralGrep, _ = pairwise_distances_argmin_min(km_grep.cluster_centers_, reducedGrep)
centralSgd, _ = pairwise_distances_argmin_min(km_sgd.cluster_centers_, reducedSgd)
centralPagerank, _ = pairwise_distances_argmin_min(km_pagerank.cluster_centers_, reducedPagerank)

# filter the centroid rows of current dataset and add feature machine_type back
kmeans_dataset = pd.read_csv("../data/reduced-kmeans_1.tsv")
sort_dataset = pd.read_csv("../data/reduced-sort_1.tsv")
grep_dataset = pd.read_csv("../data/reduced-grep_1.tsv")
sgd_dataset = pd.read_csv("../data/reduced-sgd_1.tsv")
pagerank_dataset = pd.read_csv("../data/reduced-pagerank_1.tsv")

kmeans_machine_type_column.join(kmeans_dataset)
kmeans_filter_centroids = kmeans_dataset.iloc[centralKmeans].sort_index(0, ascending=True)
kmeans_filter_centroids.to_csv('../data/kmedoids/reduced-kmeans_200.tsv', index=False)

sort_machine_type_column.join(sort_dataset)
sort_filter_centroids = sort_dataset.iloc[centralSort].sort_index(0, ascending=True)
sort_filter_centroids.to_csv('../data/kmedoids/reduced-sort_200.tsv', index=False)

grep_machine_type_column.join(grep_dataset)
grep_filter_centroids = grep_dataset.iloc[centralGrep].sort_index(0, ascending=True)
grep_filter_centroids.to_csv('../data/kmedoids/reduced-grep_200.tsv', index=False)

sgd_machine_type_column.join(sgd_dataset)
sgd_filter_centroids = sgd_dataset.iloc[centralSgd].sort_index(0, ascending=True)
sgd_filter_centroids.to_csv('../data/kmedoids/reduced-sgd_200.tsv', index=False)

pagerank_machine_type_column.join(pagerank_dataset)
pagerank_filter_centroids = pagerank_dataset.iloc[centralPagerank].sort_index(0, ascending=True)
pagerank_filter_centroids.to_csv('../data/kmedoids/reduced-pagerank_200.tsv', index=False)
# Out:
# Silhouetter Score KMeans: 0.961
# Silhouetter Score Sort: 0.631
# Silhouetter Score Grep: 0.958
# Silhouetter Score Sgd: 0.894
# Silhouetter Score Pagerank: 0.958

# %%
kmeans_compression_2 = pd.read_csv('../data/kmedoids/reduced-kmeans_200.tsv')
sort_compression_2 = pd.read_csv('../data/kmedoids/reduced-sort_200.tsv')
grep_compression_2 = pd.read_csv('../data/kmedoids/reduced-grep_200.tsv')
sgd_compression_2 = pd.read_csv('../data/kmedoids/reduced-sgd_200.tsv')
pagerank_compression_2 = pd.read_csv('../data/kmedoids/reduced-pagerank_200.tsv')

kmeans_compression_K = round(1 - (kmeans_compression_2.shape[0])/kmeans_compression_0, 4)
sort_compression_K = round(1 - (sort_compression_2.shape[0])/sort_compression_0, 4)
grep_compression_K = round(1 - (grep_compression_2.shape[0])/grep_compression_0, 4)
sgd_compression_K = round(1 - (sgd_compression_2.shape[0])/sgd_compression_0, 4)
pagerank_compression_K = round(1 - (pagerank_compression_2.shape[0])/pagerank_compression_0, 4)

print("KMeans: Compression: " + str(kmeans_compression_K) + " Datapoints: " + str(kmeans_compression_2.shape[0]))
print("Sort: Compression: " + str(sort_compression_K) + " Datapoints: " + str(sort_compression_2.shape[0]))
print("Grep: Compression: " + str(grep_compression_K) + " Datapoints: " + str(grep_compression_2.shape[0]))
print("Sgd: Compression: " + str(sgd_compression_K) + " Datapoints: " + str(sgd_compression_2.shape[0]))
print("Pagerank: Compression: " + str(pagerank_compression_K) + " Datapoints: " + str(pagerank_compression_2.shape[0]))
# Out:
# KMeans: Compression: 0.7778 Datapoints: 200
# Sort: Compression: 0.6825 Datapoints: 200
# Grep: Compression: 0.7531 Datapoints: 200
# Sgd: Compression: 0.7778 Datapoints: 200
# Pagerank: Compression: 0.8582 Datapoints: 200

# %% [markdown]
# ## Define Models

# %%
Model = collections.namedtuple('Model', ['name', 'predictor', 'kwargs'])

models = [
          Model('Ernest', EM, {}),
          Model('GBM', GB, {}), 
          
          Model('BOM', BOM, {}), 
          Model('OGB', OGB, {}), 
   
          Model('C3O', C3OPredictor, {}),
         ]

# %% [markdown]
# ## Extract Runtime Data

# %%
kmeans_df = pd.read_csv('../data/kmedoids/reduced-kmeans_200.tsv', sep='\t')
sort_df = pd.read_csv('../data/kmedoids/reduced-sort_200.tsv', sep='\t')
grep_df = pd.read_csv('../data/kmedoids/reduced-grep_200.tsv', sep='\t')
sgd_df = pd.read_csv('../data/kmedoids/reduced-sgd_200.tsv', sep='\t')
pagerank_df = pd.read_csv('../data/kmedoids/reduced-pagerank_200.tsv', sep='\t')

kmeans_dp = kmeans_df.shape[0]
sort_dp = sort_df.shape[0]
grep_dp = grep_df.shape[0]
sgd_dp = sgd_df.shape[0]
pagerank_dp = pagerank_df.shape[0]

print(kmeans_dp)
print(sort_dp)
print(grep_dp)
print(sgd_dp)
print(pagerank_dp)
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
Job = collections.namedtuple('Job', ['name', 'X', 'y'])

def get_training_data(df, features, filters):
    # Get medians
    g = df.groupby(by=['instance_count','machine_type']+features)
    df = pd.DataFrame(g.median().to_records())
    # Apply filters
    # e.g. only for one machine type each, the full c3o-experiments were conducted
    # No full cartesian product!
    for k, s, v in filters:
        if s == '==': df = df[df[k] == v]
        if s == '>' : df = df[df[k] >  v]
    X = df[['instance_count'] + features]
    y = (df[['gross_runtime']]).squeeze()
    return X, y

td = get_training_data
jobs = [
    Job('Sort',
        *(td(sort_df,
          ['data_size_MB'],
          [('machine_type', '==', 'c4.2xlarge'),
            ('line_length', '==', 100)] )) ),
    Job('Grep',
       *(td(grep_df,
           ['data_size_MB', 'p_occurrence'],
            [('machine_type', '==', 'm4.2xlarge')] )) ),
    Job('SGDLR',
        *(td(sgd_df,
            ['observations', 'features', 'iterations'],
            [('machine_type', '==', 'r4.2xlarge'),
             ('instance_count', '>', 2)] )) ),
   Job('K-Means',
        *(td(kmeans_df,
            ['observations', 'features', 'k'],
            [('machine_type', '==', 'r4.2xlarge'),
             ('instance_count', '>', 2)] )) ),
    Job('Page Rank',
        *(td(pagerank_df,
            ['links', 'pages', 'convergence_criterion'],
            [('machine_type', '==', 'r4.2xlarge')] )) ),
]

# %% [markdown]
# ## Train-Test Split Creations

# %%
def create_partial_training_data(job, splits):
    for _ in range(splits):
        yield train_test_split(job.X,job.y)

# %% [markdown]
# ### Calculating the Model Prediction Errors

# %%
def evaluate(model, X_train, X_test, y_train, y_test, error_metric):
    model_instance = model.predictor(**model.kwargs)
    model_instance.fit(X_train, y_train)
    y_pred = model_instance.predict(X_test)
    error = error_metric(y_test, y_pred)
    return error

# %%
def create_new_compression_evaluations(amount):
    with open('kmedoids_compression_results.csv', 'at') as f:
        for job in jobs:
            for split in create_partial_training_data(job, splits=amount):
                for model in models:
                    error = evaluate(model, *split, MAPE)
                    if job.name == 'K-Means':
                        f.write(f"{job.name},{model.name},{kmeans_dp},{error}\n")
                    if job.name == 'Sort':
                        f.write(f"{job.name},{model.name},{sort_dp},{error}\n")
                    if job.name == 'Grep':
                        f.write(f"{job.name},{model.name},{grep_dp},{error}\n")
                    if job.name == 'SGDLR':
                        f.write(f"{job.name},{model.name},{sgd_dp},{error}\n")
                    if job.name == 'Page Rank':
                        f.write(f"{job.name},{model.name},{pagerank_dp},{error}\n")

# %%
create_new_compression_evaluations(amount=200)

# %% [markdown]
# ### Display the Results

# %%
def read_results(job_name):
    try: results = pd.read_csv('compression_results_kmedoids.csv', header=None)
    except: return

    rres = [(job, model, ds, float(mape)) for job, model, ds, mape in results.values]
    df = pd.DataFrame(rres, columns = ('Job', 'Model', 'Compression', 'MAPE'))
    groups = df.groupby(by=['Job', 'Model', 'Compression'], as_index=False)
    df = groups.mean()
    # Filter info for just the job we are interested in
    jobdf = df[df['Job'] == job_name].set_index(['Model', 'Compression'])
    # Remove redundant info
    return jobdf.unstack()['MAPE']

def display_job_evaluation(job_name):
    
    try: displaydf = read_results(job_name)
    except: display(HTML(f"<h3>{job_name}</h3> None")); return 
    
    # Style the output to highlight the important information
    def highlight_row_min(row):
        return ['color: black' if cell == min(row) else 'color: dimgray' for cell in row]
    
    def highlight_min(data, color='aquamarine', bold=False):
        # highlight the minimum in a Series or DataFrame
        attr1 = f"background-color: {color}"
        attr2 = f"font-weight: {'bold' if bold else 'normal'}"
        if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
            is_min = data == data.min()
            return [attr1 if v else '' for v in is_min]
        else:  # from .apply(axis=None)
            is_min = data == data.min().min()
            return pd.DataFrame(np.where(is_min, attr2, ''),
                                index=data.index, columns=data.columns)
        
    table_html = displaydf.style.apply(highlight_row_min,axis=1) \
                                .apply(highlight_min, axis=0, color='aquamarine') \
                                .apply(highlight_min, axis=None, bold=True) \
                                .format("{:.2%}") \
                                ._repr_html_()
    
    display(HTML(f"<h3>{job_name}</h3>" + table_html ))

# %% [markdown]
# ### Performance of the C3O Predictor and its Constituent Models

# %%
for job in jobs:
    display_job_evaluation(job.name)
# Out:
# <h3>Sort</h3><style  type="text/css" >
# #T_4ccf9_row0_col0,#T_4ccf9_row0_col1,#T_4ccf9_row0_col2,#T_4ccf9_row0_col3,#T_4ccf9_row0_col4,#T_4ccf9_row0_col5,#T_4ccf9_row0_col6,#T_4ccf9_row0_col7,#T_4ccf9_row0_col8,#T_4ccf9_row0_col10,#T_4ccf9_row0_col11,#T_4ccf9_row0_col12,#T_4ccf9_row0_col13,#T_4ccf9_row0_col14,#T_4ccf9_row0_col15,#T_4ccf9_row0_col16,#T_4ccf9_row0_col17,#T_4ccf9_row0_col18,#T_4ccf9_row1_col0,#T_4ccf9_row1_col1,#T_4ccf9_row1_col3,#T_4ccf9_row1_col4,#T_4ccf9_row1_col5,#T_4ccf9_row1_col7,#T_4ccf9_row1_col8,#T_4ccf9_row2_col9,#T_4ccf9_row2_col10,#T_4ccf9_row2_col11,#T_4ccf9_row2_col12,#T_4ccf9_row2_col13,#T_4ccf9_row2_col14,#T_4ccf9_row2_col15,#T_4ccf9_row2_col16,#T_4ccf9_row2_col17,#T_4ccf9_row2_col18,#T_4ccf9_row3_col0,#T_4ccf9_row3_col1,#T_4ccf9_row3_col2,#T_4ccf9_row3_col3,#T_4ccf9_row3_col4,#T_4ccf9_row3_col5,#T_4ccf9_row3_col6,#T_4ccf9_row3_col7,#T_4ccf9_row3_col8,#T_4ccf9_row3_col9,#T_4ccf9_row3_col11,#T_4ccf9_row3_col12,#T_4ccf9_row3_col13,#T_4ccf9_row3_col14,#T_4ccf9_row3_col15,#T_4ccf9_row3_col16,#T_4ccf9_row3_col17,#T_4ccf9_row3_col18,#T_4ccf9_row4_col0,#T_4ccf9_row4_col1,#T_4ccf9_row4_col2,#T_4ccf9_row4_col3,#T_4ccf9_row4_col4,#T_4ccf9_row4_col5,#T_4ccf9_row4_col6,#T_4ccf9_row4_col7,#T_4ccf9_row4_col8,#T_4ccf9_row4_col9,#T_4ccf9_row4_col10,#T_4ccf9_row4_col11,#T_4ccf9_row4_col12,#T_4ccf9_row4_col13,#T_4ccf9_row4_col14,#T_4ccf9_row4_col15,#T_4ccf9_row4_col17,#T_4ccf9_row4_col18{
#             color:  dimgray;
#         }#T_4ccf9_row0_col9,#T_4ccf9_row1_col6,#T_4ccf9_row3_col10,#T_4ccf9_row4_col16{
#             color:  black;
#         }#T_4ccf9_row1_col2,#T_4ccf9_row1_col9,#T_4ccf9_row1_col10,#T_4ccf9_row1_col11,#T_4ccf9_row1_col12,#T_4ccf9_row1_col13,#T_4ccf9_row1_col14,#T_4ccf9_row1_col15,#T_4ccf9_row1_col16,#T_4ccf9_row1_col17,#T_4ccf9_row1_col18,#T_4ccf9_row2_col0,#T_4ccf9_row2_col1,#T_4ccf9_row2_col2,#T_4ccf9_row2_col3,#T_4ccf9_row2_col4,#T_4ccf9_row2_col5,#T_4ccf9_row2_col7,#T_4ccf9_row2_col8{
#             color:  dimgray;
#             background-color:  aquamarine;
#         }#T_4ccf9_row2_col6{
#             color:  black;
#             background-color:  aquamarine;
#             font-weight:  bold;
#         }</style><table id="T_4ccf9_" ><thead>    <tr>        <th class="index_name level0" >Compression</th>        <th class="col_heading level0 col0" >15</th>        <th class="col_heading level0 col1" >25</th>        <th class="col_heading level0 col2" >35</th>        <th class="col_heading level0 col3" >45</th>        <th class="col_heading level0 col4" >60</th>        <th class="col_heading level0 col5" >70</th>        <th class="col_heading level0 col6" >80</th>        <th class="col_heading level0 col7" >90</th>        <th class="col_heading level0 col8" >100</th>        <th class="col_heading level0 col9" >110</th>        <th class="col_heading level0 col10" >120</th>        <th class="col_heading level0 col11" >130</th>        <th class="col_heading level0 col12" >140</th>        <th class="col_heading level0 col13" >150</th>        <th class="col_heading level0 col14" >160</th>        <th class="col_heading level0 col15" >170</th>        <th class="col_heading level0 col16" >180</th>        <th class="col_heading level0 col17" >190</th>        <th class="col_heading level0 col18" >200</th>    </tr>    <tr>        <th class="index_name level0" >Model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ccf9_level0_row0" class="row_heading level0 row0" >BOM</th>
#                         <td id="T_4ccf9_row0_col0" class="data row0 col0" >22.49%</td>
#                         <td id="T_4ccf9_row0_col1" class="data row0 col1" >6.94%</td>
#                         <td id="T_4ccf9_row0_col2" class="data row0 col2" >23.53%</td>
#                         <td id="T_4ccf9_row0_col3" class="data row0 col3" >21.37%</td>
#                         <td id="T_4ccf9_row0_col4" class="data row0 col4" >10.56%</td>
#                         <td id="T_4ccf9_row0_col5" class="data row0 col5" >42.54%</td>
#                         <td id="T_4ccf9_row0_col6" class="data row0 col6" >18.77%</td>
#                         <td id="T_4ccf9_row0_col7" class="data row0 col7" >17.27%</td>
#                         <td id="T_4ccf9_row0_col8" class="data row0 col8" >7.98%</td>
#                         <td id="T_4ccf9_row0_col9" class="data row0 col9" >5.85%</td>
#                         <td id="T_4ccf9_row0_col10" class="data row0 col10" >6.85%</td>
#                         <td id="T_4ccf9_row0_col11" class="data row0 col11" >6.99%</td>
#                         <td id="T_4ccf9_row0_col12" class="data row0 col12" >7.48%</td>
#                         <td id="T_4ccf9_row0_col13" class="data row0 col13" >8.26%</td>
#                         <td id="T_4ccf9_row0_col14" class="data row0 col14" >7.97%</td>
#                         <td id="T_4ccf9_row0_col15" class="data row0 col15" >8.18%</td>
#                         <td id="T_4ccf9_row0_col16" class="data row0 col16" >7.69%</td>
#                         <td id="T_4ccf9_row0_col17" class="data row0 col17" >7.82%</td>
#                         <td id="T_4ccf9_row0_col18" class="data row0 col18" >7.47%</td>
#             </tr>
#             <tr>
#                         <th id="T_4ccf9_level0_row1" class="row_heading level0 row1" >C3O</th>
#                         <td id="T_4ccf9_row1_col0" class="data row1 col0" >12.69%</td>
#                         <td id="T_4ccf9_row1_col1" class="data row1 col1" >7.84%</td>
#                         <td id="T_4ccf9_row1_col2" class="data row1 col2" >7.02%</td>
#                         <td id="T_4ccf9_row1_col3" class="data row1 col3" >6.69%</td>
#                         <td id="T_4ccf9_row1_col4" class="data row1 col4" >6.84%</td>
#                         <td id="T_4ccf9_row1_col5" class="data row1 col5" >4.13%</td>
#                         <td id="T_4ccf9_row1_col6" class="data row1 col6" >3.85%</td>
#                         <td id="T_4ccf9_row1_col7" class="data row1 col7" >4.72%</td>
#                         <td id="T_4ccf9_row1_col8" class="data row1 col8" >4.50%</td>
#                         <td id="T_4ccf9_row1_col9" class="data row1 col9" >5.52%</td>
#                         <td id="T_4ccf9_row1_col10" class="data row1 col10" >5.23%</td>
#                         <td id="T_4ccf9_row1_col11" class="data row1 col11" >5.97%</td>
#                         <td id="T_4ccf9_row1_col12" class="data row1 col12" >6.62%</td>
#                         <td id="T_4ccf9_row1_col13" class="data row1 col13" >6.82%</td>
#                         <td id="T_4ccf9_row1_col14" class="data row1 col14" >6.92%</td>
#                         <td id="T_4ccf9_row1_col15" class="data row1 col15" >6.60%</td>
#                         <td id="T_4ccf9_row1_col16" class="data row1 col16" >6.62%</td>
#                         <td id="T_4ccf9_row1_col17" class="data row1 col17" >6.83%</td>
#                         <td id="T_4ccf9_row1_col18" class="data row1 col18" >6.25%</td>
#             </tr>
#             <tr>
#                         <th id="T_4ccf9_level0_row2" class="row_heading level0 row2" >Ernest</th>
#                         <td id="T_4ccf9_row2_col0" class="data row2 col0" >12.39%</td>
#                         <td id="T_4ccf9_row2_col1" class="data row2 col1" >6.27%</td>
#                         <td id="T_4ccf9_row2_col2" class="data row2 col2" >7.02%</td>
#                         <td id="T_4ccf9_row2_col3" class="data row2 col3" >5.11%</td
# <h3>Grep</h3><style  type="text/css" >
# #T_64bf7_row0_col0,#T_64bf7_row0_col1,#T_64bf7_row0_col3,#T_64bf7_row0_col4,#T_64bf7_row0_col5,#T_64bf7_row0_col6,#T_64bf7_row0_col7,#T_64bf7_row0_col8,#T_64bf7_row0_col9,#T_64bf7_row0_col10,#T_64bf7_row0_col11,#T_64bf7_row0_col12,#T_64bf7_row0_col13,#T_64bf7_row0_col14,#T_64bf7_row0_col15,#T_64bf7_row0_col16,#T_64bf7_row0_col17,#T_64bf7_row0_col18,#T_64bf7_row1_col0,#T_64bf7_row1_col1,#T_64bf7_row1_col4,#T_64bf7_row1_col5,#T_64bf7_row1_col9,#T_64bf7_row1_col10,#T_64bf7_row1_col11,#T_64bf7_row1_col12,#T_64bf7_row1_col13,#T_64bf7_row1_col14,#T_64bf7_row1_col15,#T_64bf7_row1_col17,#T_64bf7_row2_col2,#T_64bf7_row2_col3,#T_64bf7_row2_col4,#T_64bf7_row2_col5,#T_64bf7_row2_col6,#T_64bf7_row2_col7,#T_64bf7_row2_col8,#T_64bf7_row2_col9,#T_64bf7_row2_col10,#T_64bf7_row2_col11,#T_64bf7_row2_col12,#T_64bf7_row2_col13,#T_64bf7_row2_col14,#T_64bf7_row2_col15,#T_64bf7_row2_col16,#T_64bf7_row2_col17,#T_64bf7_row2_col18,#T_64bf7_row3_col0,#T_64bf7_row3_col2,#T_64bf7_row3_col3,#T_64bf7_row3_col6,#T_64bf7_row3_col7,#T_64bf7_row3_col8,#T_64bf7_row3_col16,#T_64bf7_row4_col0,#T_64bf7_row4_col1,#T_64bf7_row4_col2,#T_64bf7_row4_col3,#T_64bf7_row4_col4,#T_64bf7_row4_col5,#T_64bf7_row4_col6,#T_64bf7_row4_col7,#T_64bf7_row4_col8,#T_64bf7_row4_col9,#T_64bf7_row4_col10,#T_64bf7_row4_col11,#T_64bf7_row4_col12,#T_64bf7_row4_col13,#T_64bf7_row4_col14,#T_64bf7_row4_col15,#T_64bf7_row4_col16,#T_64bf7_row4_col17{
#             color:  dimgray;
#         }#T_64bf7_row0_col2,#T_64bf7_row1_col18,#T_64bf7_row2_col1,#T_64bf7_row4_col18{
#             color:  black;
#         }#T_64bf7_row1_col2,#T_64bf7_row1_col3,#T_64bf7_row1_col6,#T_64bf7_row1_col7,#T_64bf7_row1_col8,#T_64bf7_row1_col16,#T_64bf7_row2_col0,#T_64bf7_row3_col1,#T_64bf7_row3_col4,#T_64bf7_row3_col5,#T_64bf7_row3_col9,#T_64bf7_row3_col10,#T_64bf7_row3_col11,#T_64bf7_row3_col12,#T_64bf7_row3_col13,#T_64bf7_row3_col14,#T_64bf7_row3_col15,#T_64bf7_row3_col17{
#             color:  dimgray;
#             background-color:  aquamarine;
#         }#T_64bf7_row3_col18{
#             color:  black;
#             background-color:  aquamarine;
#             font-weight:  bold;
#         }</style><table id="T_64bf7_" ><thead>    <tr>        <th class="index_name level0" >Compression</th>        <th class="col_heading level0 col0" >15</th>        <th class="col_heading level0 col1" >25</th>        <th class="col_heading level0 col2" >35</th>        <th class="col_heading level0 col3" >45</th>        <th class="col_heading level0 col4" >60</th>        <th class="col_heading level0 col5" >70</th>        <th class="col_heading level0 col6" >80</th>        <th class="col_heading level0 col7" >90</th>        <th class="col_heading level0 col8" >100</th>        <th class="col_heading level0 col9" >110</th>        <th class="col_heading level0 col10" >120</th>        <th class="col_heading level0 col11" >130</th>        <th class="col_heading level0 col12" >140</th>        <th class="col_heading level0 col13" >150</th>        <th class="col_heading level0 col14" >160</th>        <th class="col_heading level0 col15" >170</th>        <th class="col_heading level0 col16" >180</th>        <th class="col_heading level0 col17" >190</th>        <th class="col_heading level0 col18" >200</th>    </tr>    <tr>        <th class="index_name level0" >Model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64bf7_level0_row0" class="row_heading level0 row0" >BOM</th>
#                         <td id="T_64bf7_row0_col0" class="data row0 col0" >24.77%</td>
#                         <td id="T_64bf7_row0_col1" class="data row0 col1" >22.04%</td>
#                         <td id="T_64bf7_row0_col2" class="data row0 col2" >12.23%</td>
#                         <td id="T_64bf7_row0_col3" class="data row0 col3" >18.91%</td>
#                         <td id="T_64bf7_row0_col4" class="data row0 col4" >21.77%</td>
#                         <td id="T_64bf7_row0_col5" class="data row0 col5" >18.53%</td>
#                         <td id="T_64bf7_row0_col6" class="data row0 col6" >19.65%</td>
#                         <td id="T_64bf7_row0_col7" class="data row0 col7" >18.20%</td>
#                         <td id="T_64bf7_row0_col8" class="data row0 col8" >20.43%</td>
#                         <td id="T_64bf7_row0_col9" class="data row0 col9" >18.10%</td>
#                         <td id="T_64bf7_row0_col10" class="data row0 col10" >17.24%</td>
#                         <td id="T_64bf7_row0_col11" class="data row0 col11" >15.79%</td>
#                         <td id="T_64bf7_row0_col12" class="data row0 col12" >15.58%</td>
#                         <td id="T_64bf7_row0_col13" class="data row0 col13" >16.51%</td>
#                         <td id="T_64bf7_row0_col14" class="data row0 col14" >16.22%</td>
#                         <td id="T_64bf7_row0_col15" class="data row0 col15" >16.50%</td>
#                         <td id="T_64bf7_row0_col16" class="data row0 col16" >16.60%</td>
#                         <td id="T_64bf7_row0_col17" class="data row0 col17" >16.05%</td>
#                         <td id="T_64bf7_row0_col18" class="data row0 col18" >15.56%</td>
#             </tr>
#             <tr>
#                         <th id="T_64bf7_level0_row1" class="row_heading level0 row1" >C3O</th>
#                         <td id="T_64bf7_row1_col0" class="data row1 col0" >19.06%</td>
#                         <td id="T_64bf7_row1_col1" class="data row1 col1" >13.03%</td>
#                         <td id="T_64bf7_row1_col2" class="data row1 col2" >9.23%</td>
#                         <td id="T_64bf7_row1_col3" class="data row1 col3" >10.01%</td>
#                         <td id="T_64bf7_row1_col4" class="data row1 col4" >14.97%</td>
#                         <td id="T_64bf7_row1_col5" class="data row1 col5" >10.24%</td>
#                         <td id="T_64bf7_row1_col6" class="data row1 col6" >16.49%</td>
#                         <td id="T_64bf7_row1_col7" class="data row1 col7" >15.26%</td>
#                         <td id="T_64bf7_row1_col8" class="data row1 col8" >13.89%</td>
#                         <td id="T_64bf7_row1_col9" class="data row1 col9" >12.45%</td>
#                         <td id="T_64bf7_row1_col10" class="data row1 col10" >11.27%</td>
#                         <td id="T_64bf7_row1_col11" class="data row1 col11" >9.38%</td>
#                         <td id="T_64bf7_row1_col12" class="data row1 col12" >9.59%</td>
#                         <td id="T_64bf7_row1_col13" class="data row1 col13" >6.49%</td>
#                         <td id="T_64bf7_row1_col14" class="data row1 col14" >5.86%</td>
#                         <td id="T_64bf7_row1_col15" class="data row1 col15" >5.73%</td>
#                         <td id="T_64bf7_row1_col16" class="data row1 col16" >5.79%</td>
#                         <td id="T_64bf7_row1_col17" class="data row1 col17" >5.84%</td>
#                         <td id="T_64bf7_row1_col18" class="data row1 col18" >4.24%</td>
#             </tr>
#             <tr>
#                         <th id="T_64bf7_level0_row2" class="row_heading level0 row2" >Ernest</th>
#                         <td id="T_64bf7_row2_col0" class="data row2 col0" >15.73%</td>
#                         <td id="T_64bf7_row2_col1" class="data row2 col1" >12.50%</td>
#                         <td id="T_64bf7_row2_col2" class="data row2 col2" >12.60%</td>
#                         <td id="T_64bf7_row2_col3" class="dat
# <h3>SGDLR</h3><style  type="text/css" >
# #T_5d29c_row0_col0,#T_5d29c_row0_col2,#T_5d29c_row0_col3,#T_5d29c_row0_col5,#T_5d29c_row0_col6,#T_5d29c_row0_col7,#T_5d29c_row0_col8,#T_5d29c_row0_col9,#T_5d29c_row0_col10,#T_5d29c_row0_col11,#T_5d29c_row0_col12,#T_5d29c_row0_col13,#T_5d29c_row0_col14,#T_5d29c_row0_col15,#T_5d29c_row0_col16,#T_5d29c_row0_col17,#T_5d29c_row0_col18,#T_5d29c_row1_col0,#T_5d29c_row1_col1,#T_5d29c_row1_col9,#T_5d29c_row1_col10,#T_5d29c_row1_col11,#T_5d29c_row1_col12,#T_5d29c_row1_col13,#T_5d29c_row1_col14,#T_5d29c_row1_col15,#T_5d29c_row1_col16,#T_5d29c_row1_col18,#T_5d29c_row2_col1,#T_5d29c_row2_col3,#T_5d29c_row2_col4,#T_5d29c_row2_col5,#T_5d29c_row2_col6,#T_5d29c_row2_col7,#T_5d29c_row2_col8,#T_5d29c_row2_col9,#T_5d29c_row2_col10,#T_5d29c_row2_col11,#T_5d29c_row2_col12,#T_5d29c_row2_col13,#T_5d29c_row2_col14,#T_5d29c_row2_col15,#T_5d29c_row2_col16,#T_5d29c_row2_col17,#T_5d29c_row2_col18,#T_5d29c_row3_col0,#T_5d29c_row3_col1,#T_5d29c_row3_col2,#T_5d29c_row3_col3,#T_5d29c_row3_col4,#T_5d29c_row3_col5,#T_5d29c_row3_col6,#T_5d29c_row3_col7,#T_5d29c_row3_col8,#T_5d29c_row4_col0,#T_5d29c_row4_col1,#T_5d29c_row4_col2,#T_5d29c_row4_col3,#T_5d29c_row4_col4,#T_5d29c_row4_col5,#T_5d29c_row4_col6,#T_5d29c_row4_col7,#T_5d29c_row4_col8,#T_5d29c_row4_col9,#T_5d29c_row4_col10,#T_5d29c_row4_col11,#T_5d29c_row4_col12,#T_5d29c_row4_col14,#T_5d29c_row4_col15,#T_5d29c_row4_col16,#T_5d29c_row4_col17,#T_5d29c_row4_col18{
#             color:  dimgray;
#         }#T_5d29c_row0_col1,#T_5d29c_row1_col2,#T_5d29c_row1_col3,#T_5d29c_row1_col4,#T_5d29c_row1_col5,#T_5d29c_row1_col6,#T_5d29c_row1_col7,#T_5d29c_row1_col8,#T_5d29c_row2_col0,#T_5d29c_row3_col9,#T_5d29c_row3_col10,#T_5d29c_row3_col11,#T_5d29c_row3_col12,#T_5d29c_row3_col13,#T_5d29c_row3_col14,#T_5d29c_row3_col15,#T_5d29c_row3_col16,#T_5d29c_row3_col18{
#             color:  dimgray;
#             background-color:  aquamarine;
#         }#T_5d29c_row0_col4,#T_5d29c_row1_col17,#T_5d29c_row2_col2,#T_5d29c_row4_col13{
#             color:  black;
#         }#T_5d29c_row3_col17{
#             color:  black;
#             background-color:  aquamarine;
#             font-weight:  bold;
#         }</style><table id="T_5d29c_" ><thead>    <tr>        <th class="index_name level0" >Compression</th>        <th class="col_heading level0 col0" >15</th>        <th class="col_heading level0 col1" >25</th>        <th class="col_heading level0 col2" >35</th>        <th class="col_heading level0 col3" >45</th>        <th class="col_heading level0 col4" >60</th>        <th class="col_heading level0 col5" >70</th>        <th class="col_heading level0 col6" >80</th>        <th class="col_heading level0 col7" >90</th>        <th class="col_heading level0 col8" >100</th>        <th class="col_heading level0 col9" >110</th>        <th class="col_heading level0 col10" >120</th>        <th class="col_heading level0 col11" >130</th>        <th class="col_heading level0 col12" >140</th>        <th class="col_heading level0 col13" >150</th>        <th class="col_heading level0 col14" >160</th>        <th class="col_heading level0 col15" >170</th>        <th class="col_heading level0 col16" >180</th>        <th class="col_heading level0 col17" >190</th>        <th class="col_heading level0 col18" >200</th>    </tr>    <tr>        <th class="index_name level0" >Model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5d29c_level0_row0" class="row_heading level0 row0" >BOM</th>
#                         <td id="T_5d29c_row0_col0" class="data row0 col0" >18.76%</td>
#                         <td id="T_5d29c_row0_col1" class="data row0 col1" >11.54%</td>
#                         <td id="T_5d29c_row0_col2" class="data row0 col2" >13.93%</td>
#                         <td id="T_5d29c_row0_col3" class="data row0 col3" >11.36%</td>
#                         <td id="T_5d29c_row0_col4" class="data row0 col4" >9.94%</td>
#                         <td id="T_5d29c_row0_col5" class="data row0 col5" >10.89%</td>
#                         <td id="T_5d29c_row0_col6" class="data row0 col6" >13.15%</td>
#                         <td id="T_5d29c_row0_col7" class="data row0 col7" >13.37%</td>
#                         <td id="T_5d29c_row0_col8" class="data row0 col8" >12.67%</td>
#                         <td id="T_5d29c_row0_col9" class="data row0 col9" >13.50%</td>
#                         <td id="T_5d29c_row0_col10" class="data row0 col10" >12.66%</td>
#                         <td id="T_5d29c_row0_col11" class="data row0 col11" >12.84%</td>
#                         <td id="T_5d29c_row0_col12" class="data row0 col12" >12.61%</td>
#                         <td id="T_5d29c_row0_col13" class="data row0 col13" >12.90%</td>
#                         <td id="T_5d29c_row0_col14" class="data row0 col14" >12.63%</td>
#                         <td id="T_5d29c_row0_col15" class="data row0 col15" >12.56%</td>
#                         <td id="T_5d29c_row0_col16" class="data row0 col16" >12.70%</td>
#                         <td id="T_5d29c_row0_col17" class="data row0 col17" >12.72%</td>
#                         <td id="T_5d29c_row0_col18" class="data row0 col18" >12.52%</td>
#             </tr>
#             <tr>
#                         <th id="T_5d29c_level0_row1" class="row_heading level0 row1" >C3O</th>
#                         <td id="T_5d29c_row1_col0" class="data row1 col0" >16.01%</td>
#                         <td id="T_5d29c_row1_col1" class="data row1 col1" >13.32%</td>
#                         <td id="T_5d29c_row1_col2" class="data row1 col2" >13.62%</td>
#                         <td id="T_5d29c_row1_col3" class="data row1 col3" >11.22%</td>
#                         <td id="T_5d29c_row1_col4" class="data row1 col4" >9.69%</td>
#                         <td id="T_5d29c_row1_col5" class="data row1 col5" >10.46%</td>
#                         <td id="T_5d29c_row1_col6" class="data row1 col6" >10.03%</td>
#                         <td id="T_5d29c_row1_col7" class="data row1 col7" >9.75%</td>
#                         <td id="T_5d29c_row1_col8" class="data row1 col8" >7.68%</td>
#                         <td id="T_5d29c_row1_col9" class="data row1 col9" >7.58%</td>
#                         <td id="T_5d29c_row1_col10" class="data row1 col10" >6.81%</td>
#                         <td id="T_5d29c_row1_col11" class="data row1 col11" >5.69%</td>
#                         <td id="T_5d29c_row1_col12" class="data row1 col12" >5.09%</td>
#                         <td id="T_5d29c_row1_col13" class="data row1 col13" >4.69%</td>
#                         <td id="T_5d29c_row1_col14" class="data row1 col14" >4.01%</td>
#                         <td id="T_5d29c_row1_col15" class="data row1 col15" >3.76%</td>
#                         <td id="T_5d29c_row1_col16" class="data row1 col16" >3.40%</td>
#                         <td id="T_5d29c_row1_col17" class="data row1 col17" >3.15%</td>
#                         <td id="T_5d29c_row1_col18" class="data row1 col18" >3.19%</td>
#             </tr>
#             <tr>
#                         <th id="T_5d29c_level0_row2" class="row_heading level0 row2" >Ernest</th>
#                         <td id="T_5d29c_row2_col0" class="data row2 col0" >14.67%</td>
#                         <td id="T_5d29c_row2_col1" class="data row2 col1" >14.44%</td>
#                         <td id="T_5d29c_row2_col2" class="data row2 col2" >14.15%</td>
#                         <td id="T_5d29c_row2_col3" class="data ro
# <h3>K-Means</h3><style  type="text/css" >
# #T_747f6_row0_col0,#T_747f6_row0_col1,#T_747f6_row0_col4,#T_747f6_row0_col6,#T_747f6_row0_col7,#T_747f6_row0_col9,#T_747f6_row0_col10,#T_747f6_row0_col11,#T_747f6_row0_col12,#T_747f6_row0_col14,#T_747f6_row0_col15,#T_747f6_row0_col16,#T_747f6_row0_col17,#T_747f6_row0_col18,#T_747f6_row1_col0,#T_747f6_row1_col1,#T_747f6_row1_col2,#T_747f6_row1_col3,#T_747f6_row1_col5,#T_747f6_row1_col6,#T_747f6_row1_col8,#T_747f6_row1_col12,#T_747f6_row1_col14,#T_747f6_row1_col15,#T_747f6_row1_col16,#T_747f6_row1_col17,#T_747f6_row2_col2,#T_747f6_row2_col3,#T_747f6_row2_col4,#T_747f6_row2_col5,#T_747f6_row2_col6,#T_747f6_row2_col7,#T_747f6_row2_col8,#T_747f6_row2_col9,#T_747f6_row2_col10,#T_747f6_row2_col11,#T_747f6_row2_col12,#T_747f6_row2_col13,#T_747f6_row2_col14,#T_747f6_row2_col15,#T_747f6_row2_col16,#T_747f6_row2_col17,#T_747f6_row2_col18,#T_747f6_row3_col0,#T_747f6_row3_col1,#T_747f6_row3_col2,#T_747f6_row3_col3,#T_747f6_row3_col4,#T_747f6_row3_col5,#T_747f6_row3_col7,#T_747f6_row3_col8,#T_747f6_row3_col9,#T_747f6_row3_col10,#T_747f6_row3_col11,#T_747f6_row3_col13,#T_747f6_row4_col0,#T_747f6_row4_col1,#T_747f6_row4_col2,#T_747f6_row4_col3,#T_747f6_row4_col4,#T_747f6_row4_col5,#T_747f6_row4_col6,#T_747f6_row4_col7,#T_747f6_row4_col8,#T_747f6_row4_col9,#T_747f6_row4_col10,#T_747f6_row4_col11,#T_747f6_row4_col12,#T_747f6_row4_col13,#T_747f6_row4_col14,#T_747f6_row4_col15,#T_747f6_row4_col16,#T_747f6_row4_col17{
#             color:  dimgray;
#         }#T_747f6_row0_col2,#T_747f6_row0_col3,#T_747f6_row0_col5,#T_747f6_row0_col8,#T_747f6_row1_col4,#T_747f6_row1_col7,#T_747f6_row1_col9,#T_747f6_row1_col10,#T_747f6_row1_col11,#T_747f6_row1_col13,#T_747f6_row2_col0,#T_747f6_row3_col6,#T_747f6_row3_col12,#T_747f6_row3_col14,#T_747f6_row3_col15,#T_747f6_row3_col16,#T_747f6_row3_col17{
#             color:  dimgray;
#             background-color:  aquamarine;
#         }#T_747f6_row0_col13,#T_747f6_row1_col18,#T_747f6_row4_col18{
#             color:  black;
#         }#T_747f6_row2_col1{
#             color:  black;
#             background-color:  aquamarine;
#         }#T_747f6_row3_col18{
#             color:  black;
#             background-color:  aquamarine;
#             font-weight:  bold;
#         }</style><table id="T_747f6_" ><thead>    <tr>        <th class="index_name level0" >Compression</th>        <th class="col_heading level0 col0" >15</th>        <th class="col_heading level0 col1" >25</th>        <th class="col_heading level0 col2" >35</th>        <th class="col_heading level0 col3" >45</th>        <th class="col_heading level0 col4" >60</th>        <th class="col_heading level0 col5" >70</th>        <th class="col_heading level0 col6" >80</th>        <th class="col_heading level0 col7" >90</th>        <th class="col_heading level0 col8" >100</th>        <th class="col_heading level0 col9" >110</th>        <th class="col_heading level0 col10" >120</th>        <th class="col_heading level0 col11" >130</th>        <th class="col_heading level0 col12" >140</th>        <th class="col_heading level0 col13" >150</th>        <th class="col_heading level0 col14" >160</th>        <th class="col_heading level0 col15" >170</th>        <th class="col_heading level0 col16" >180</th>        <th class="col_heading level0 col17" >190</th>        <th class="col_heading level0 col18" >200</th>    </tr>    <tr>        <th class="index_name level0" >Model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_747f6_level0_row0" class="row_heading level0 row0" >BOM</th>
#                         <td id="T_747f6_row0_col0" class="data row0 col0" >23.67%</td>
#                         <td id="T_747f6_row0_col1" class="data row0 col1" >14.46%</td>
#                         <td id="T_747f6_row0_col2" class="data row0 col2" >10.26%</td>
#                         <td id="T_747f6_row0_col3" class="data row0 col3" >10.51%</td>
#                         <td id="T_747f6_row0_col4" class="data row0 col4" >10.31%</td>
#                         <td id="T_747f6_row0_col5" class="data row0 col5" >9.76%</td>
#                         <td id="T_747f6_row0_col6" class="data row0 col6" >12.14%</td>
#                         <td id="T_747f6_row0_col7" class="data row0 col7" >9.57%</td>
#                         <td id="T_747f6_row0_col8" class="data row0 col8" >9.26%</td>
#                         <td id="T_747f6_row0_col9" class="data row0 col9" >11.23%</td>
#                         <td id="T_747f6_row0_col10" class="data row0 col10" >8.90%</td>
#                         <td id="T_747f6_row0_col11" class="data row0 col11" >7.90%</td>
#                         <td id="T_747f6_row0_col12" class="data row0 col12" >6.37%</td>
#                         <td id="T_747f6_row0_col13" class="data row0 col13" >6.23%</td>
#                         <td id="T_747f6_row0_col14" class="data row0 col14" >6.46%</td>
#                         <td id="T_747f6_row0_col15" class="data row0 col15" >6.86%</td>
#                         <td id="T_747f6_row0_col16" class="data row0 col16" >6.86%</td>
#                         <td id="T_747f6_row0_col17" class="data row0 col17" >6.62%</td>
#                         <td id="T_747f6_row0_col18" class="data row0 col18" >6.50%</td>
#             </tr>
#             <tr>
#                         <th id="T_747f6_level0_row1" class="row_heading level0 row1" >C3O</th>
#                         <td id="T_747f6_row1_col0" class="data row1 col0" >13.15%</td>
#                         <td id="T_747f6_row1_col1" class="data row1 col1" >11.20%</td>
#                         <td id="T_747f6_row1_col2" class="data row1 col2" >10.93%</td>
#                         <td id="T_747f6_row1_col3" class="data row1 col3" >10.51%</td>
#                         <td id="T_747f6_row1_col4" class="data row1 col4" >10.19%</td>
#                         <td id="T_747f6_row1_col5" class="data row1 col5" >10.09%</td>
#                         <td id="T_747f6_row1_col6" class="data row1 col6" >10.95%</td>
#                         <td id="T_747f6_row1_col7" class="data row1 col7" >9.25%</td>
#                         <td id="T_747f6_row1_col8" class="data row1 col8" >9.26%</td>
#                         <td id="T_747f6_row1_col9" class="data row1 col9" >8.74%</td>
#                         <td id="T_747f6_row1_col10" class="data row1 col10" >7.74%</td>
#                         <td id="T_747f6_row1_col11" class="data row1 col11" >6.92%</td>
#                         <td id="T_747f6_row1_col12" class="data row1 col12" >6.20%</td>
#                         <td id="T_747f6_row1_col13" class="data row1 col13" >5.86%</td>
#                         <td id="T_747f6_row1_col14" class="data row1 col14" >5.60%</td>
#                         <td id="T_747f6_row1_col15" class="data row1 col15" >4.86%</td>
#                         <td id="T_747f6_row1_col16" class="data row1 col16" >4.52%</td>
#                         <td id="T_747f6_row1_col17" class="data row1 col17" >4.08%</td>
#                         <td id="T_747f6_row1_col18" class="data row1 col18" >4.05%</td>
#             </tr>
#             <tr>
#                         <th id="T_747f6_level0_row2" class="row_heading level0 row2" >Ernest</th>
#                         <td id="T_747f6_row2_col0" class="data row2 col0" >10.36%</td>
#                         <td id="T_747f6_row2_col1" class="data row2 col1" >9.64%</td>
#                         <td id="T_747f6_row2_col2" class="data row2 col2" >11.00%
# <h3>Page Rank</h3><style  type="text/css" >
# #T_8db1f_row0_col0,#T_8db1f_row1_col4,#T_8db1f_row1_col5,#T_8db1f_row1_col6,#T_8db1f_row1_col7,#T_8db1f_row1_col8,#T_8db1f_row1_col9,#T_8db1f_row1_col10,#T_8db1f_row1_col11,#T_8db1f_row1_col12,#T_8db1f_row1_col13,#T_8db1f_row1_col14,#T_8db1f_row1_col15,#T_8db1f_row1_col16,#T_8db1f_row1_col17,#T_8db1f_row4_col1,#T_8db1f_row4_col2,#T_8db1f_row4_col3{
#             color:  dimgray;
#             background-color:  aquamarine;
#         }#T_8db1f_row0_col1,#T_8db1f_row0_col2,#T_8db1f_row0_col4,#T_8db1f_row0_col5,#T_8db1f_row0_col6,#T_8db1f_row0_col7,#T_8db1f_row0_col8,#T_8db1f_row0_col9,#T_8db1f_row0_col10,#T_8db1f_row0_col11,#T_8db1f_row0_col12,#T_8db1f_row0_col13,#T_8db1f_row0_col14,#T_8db1f_row0_col15,#T_8db1f_row0_col16,#T_8db1f_row0_col17,#T_8db1f_row0_col18,#T_8db1f_row1_col0,#T_8db1f_row1_col1,#T_8db1f_row1_col2,#T_8db1f_row1_col3,#T_8db1f_row2_col0,#T_8db1f_row2_col1,#T_8db1f_row2_col2,#T_8db1f_row2_col3,#T_8db1f_row2_col4,#T_8db1f_row2_col6,#T_8db1f_row2_col7,#T_8db1f_row2_col8,#T_8db1f_row2_col9,#T_8db1f_row2_col10,#T_8db1f_row2_col11,#T_8db1f_row2_col12,#T_8db1f_row2_col13,#T_8db1f_row2_col14,#T_8db1f_row2_col15,#T_8db1f_row2_col16,#T_8db1f_row2_col17,#T_8db1f_row2_col18,#T_8db1f_row3_col0,#T_8db1f_row3_col1,#T_8db1f_row3_col2,#T_8db1f_row3_col3,#T_8db1f_row3_col4,#T_8db1f_row3_col5,#T_8db1f_row3_col6,#T_8db1f_row3_col7,#T_8db1f_row3_col8,#T_8db1f_row3_col9,#T_8db1f_row3_col10,#T_8db1f_row3_col11,#T_8db1f_row3_col12,#T_8db1f_row3_col13,#T_8db1f_row3_col14,#T_8db1f_row3_col15,#T_8db1f_row3_col16,#T_8db1f_row3_col17,#T_8db1f_row4_col0,#T_8db1f_row4_col4,#T_8db1f_row4_col5,#T_8db1f_row4_col6,#T_8db1f_row4_col7,#T_8db1f_row4_col8,#T_8db1f_row4_col9,#T_8db1f_row4_col10,#T_8db1f_row4_col11,#T_8db1f_row4_col12,#T_8db1f_row4_col13,#T_8db1f_row4_col14,#T_8db1f_row4_col15,#T_8db1f_row4_col16,#T_8db1f_row4_col17{
#             color:  dimgray;
#         }#T_8db1f_row0_col3,#T_8db1f_row2_col5,#T_8db1f_row3_col18,#T_8db1f_row4_col18{
#             color:  black;
#         }#T_8db1f_row1_col18{
#             color:  black;
#             background-color:  aquamarine;
#             font-weight:  bold;
#         }</style><table id="T_8db1f_" ><thead>    <tr>        <th class="index_name level0" >Compression</th>        <th class="col_heading level0 col0" >15</th>        <th class="col_heading level0 col1" >25</th>        <th class="col_heading level0 col2" >35</th>        <th class="col_heading level0 col3" >45</th>        <th class="col_heading level0 col4" >60</th>        <th class="col_heading level0 col5" >70</th>        <th class="col_heading level0 col6" >80</th>        <th class="col_heading level0 col7" >90</th>        <th class="col_heading level0 col8" >100</th>        <th class="col_heading level0 col9" >110</th>        <th class="col_heading level0 col10" >120</th>        <th class="col_heading level0 col11" >130</th>        <th class="col_heading level0 col12" >140</th>        <th class="col_heading level0 col13" >150</th>        <th class="col_heading level0 col14" >160</th>        <th class="col_heading level0 col15" >170</th>        <th class="col_heading level0 col16" >180</th>        <th class="col_heading level0 col17" >190</th>        <th class="col_heading level0 col18" >200</th>    </tr>    <tr>        <th class="index_name level0" >Model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8db1f_level0_row0" class="row_heading level0 row0" >BOM</th>
#                         <td id="T_8db1f_row0_col0" class="data row0 col0" >11.18%</td>
#                         <td id="T_8db1f_row0_col1" class="data row0 col1" >9.03%</td>
#                         <td id="T_8db1f_row0_col2" class="data row0 col2" >8.36%</td>
#                         <td id="T_8db1f_row0_col3" class="data row0 col3" >8.12%</td>
#                         <td id="T_8db1f_row0_col4" class="data row0 col4" >8.50%</td>
#                         <td id="T_8db1f_row0_col5" class="data row0 col5" >9.69%</td>
#                         <td id="T_8db1f_row0_col6" class="data row0 col6" >11.77%</td>
#                         <td id="T_8db1f_row0_col7" class="data row0 col7" >13.40%</td>
#                         <td id="T_8db1f_row0_col8" class="data row0 col8" >17.63%</td>
#                         <td id="T_8db1f_row0_col9" class="data row0 col9" >16.68%</td>
#                         <td id="T_8db1f_row0_col10" class="data row0 col10" >15.65%</td>
#                         <td id="T_8db1f_row0_col11" class="data row0 col11" >16.00%</td>
#                         <td id="T_8db1f_row0_col12" class="data row0 col12" >17.10%</td>
#                         <td id="T_8db1f_row0_col13" class="data row0 col13" >15.82%</td>
#                         <td id="T_8db1f_row0_col14" class="data row0 col14" >16.17%</td>
#                         <td id="T_8db1f_row0_col15" class="data row0 col15" >15.70%</td>
#                         <td id="T_8db1f_row0_col16" class="data row0 col16" >15.85%</td>
#                         <td id="T_8db1f_row0_col17" class="data row0 col17" >15.34%</td>
#                         <td id="T_8db1f_row0_col18" class="data row0 col18" >15.99%</td>
#             </tr>
#             <tr>
#                         <th id="T_8db1f_level0_row1" class="row_heading level0 row1" >C3O</th>
#                         <td id="T_8db1f_row1_col0" class="data row1 col0" >12.13%</td>
#                         <td id="T_8db1f_row1_col1" class="data row1 col1" >8.35%</td>
#                         <td id="T_8db1f_row1_col2" class="data row1 col2" >6.41%</td>
#                         <td id="T_8db1f_row1_col3" class="data row1 col3" >4.97%</td>
#                         <td id="T_8db1f_row1_col4" class="data row1 col4" >4.38%</td>
#                         <td id="T_8db1f_row1_col5" class="data row1 col5" >6.85%</td>
#                         <td id="T_8db1f_row1_col6" class="data row1 col6" >6.90%</td>
#                         <td id="T_8db1f_row1_col7" class="data row1 col7" >7.15%</td>
#                         <td id="T_8db1f_row1_col8" class="data row1 col8" >6.69%</td>
#                         <td id="T_8db1f_row1_col9" class="data row1 col9" >5.98%</td>
#                         <td id="T_8db1f_row1_col10" class="data row1 col10" >5.29%</td>
#                         <td id="T_8db1f_row1_col11" class="data row1 col11" >4.42%</td>
#                         <td id="T_8db1f_row1_col12" class="data row1 col12" >4.40%</td>
#                         <td id="T_8db1f_row1_col13" class="data row1 col13" >4.63%</td>
#                         <td id="T_8db1f_row1_col14" class="data row1 col14" >4.66%</td>
#                         <td id="T_8db1f_row1_col15" class="data row1 col15" >4.54%</td>
#                         <td id="T_8db1f_row1_col16" class="data row1 col16" >4.76%</td>
#                         <td id="T_8db1f_row1_col17" class="data row1 col17" >4.26%</td>
#                         <td id="T_8db1f_row1_col18" class="data row1 col18" >4.08%</td>
#             </tr>
#             <tr>
#                         <th id="T_8db1f_level0_row2" class="row_heading level0 row2" >Ernest</th>
#                         <td id="T_8db1f_row2_col0" class="data row2 col0" >28.93%</td>
#                         <td id="T_8db1f_row2_col1" class="data row2 col1" >32.08%</td>
#                         <td id="T_8db1f_row2_col2" class="data row2 col2" >27.96%</td>
#                         <td id="T_8db1f_row2_col3" class="data row2 co

# %%
ff = 'DejaVu Sans'
ff = 'DejaVu Serif'
matplotlib.rc('font', family=ff)

model_names = list(map(lambda m:m.name, models))

colors = ['tab:blue', 'tab:green', 'red', 'tab:orange', 'black']

plt.figure(figsize=(8,8))
for i, job in enumerate(jobs):
    results = read_results(job.name)
    plt.subplot(3,2,i+1)
    plt.title(job.name, fontsize=17)
    for j, model_name in enumerate(model_names):
        y = results.loc[model_name][:]
        x =  results.loc[model_name].keys()
        line = plt.plot(x, y, '--' if model_name=='C3O' else '-', label=model_name, color=colors[j])
        
        plt.xlabel('Datenpunkte', fontsize=15)
        plt.ylabel('MAPE', fontsize=15)
        
        plt.ylim(0, .45)

plt.figlegend(model_names, fontsize=15, loc='lower center', ncol=1, bbox_to_anchor=[0.78, +.07], 
              bbox_transform=plt.gcf().transFigure)
plt.tight_layout()
plt.savefig('compression_kmedoids.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Display DBSCAN vs. KMEANS vs. KMEDOIDS

# %%
for job in jobs:
    results = pd.read_csv('kmedoids_vs_compression_results.csv', header=None)
    rres = [(job, model, ds, float(mape)) for job, model, ds, mape in results.values]
    df = pd.DataFrame(rres, columns = ('Job', 'Model', 'Compression', 'MAPE'))
    groups = df.groupby(by=['Job', 'Model', 'Compression'], as_index=False)
    df = groups.mean()
    # Filter info for just the job we are interested in
    jobdf = df[df['Job'] == job.name].set_index(['Model', 'Compression'])

c3oResults = df[df['Model'] == 'C3O'].iloc[::-1]
with open('dbscan_vs_kmeans_vs_kmedoids.csv', 'at') as f:
    for i in range(5):
        f.write(f"{'C3O-KMEDOIDS'},{i},{c3oResults.iloc[i::5, :].mean().values[1]}\n")
        print(c3oResults.iloc[i::5, :].mean().values[1])
# Out:
# 0.036211353158150515
# 0.0352092553064755
# 0.0478940102786458
# 0.08562887274730754
# 0.09187317905605039

# %%
Model = collections.namedtuple('Model', ['name', 'predictor', 'kwargs'])

models = [
          Model('C3O-DBSCAN', C3OPredictor, {}),
          Model('C3O-KMEANS', C3OPredictor, {}),
         ]

def read_results_all_jobs():
    try: results = pd.read_csv('dbscan_vs_kmeans_vs_kmedoids.csv', header=None)
    except: return

    rres = [(model, ds, float(mape)) for model, ds, mape in results.values]
    df = pd.DataFrame(rres, columns = ('Model', 'Compression', 'MAPE'))
    groups = df.groupby(by=['Model', 'Compression'], as_index=False)
    df = groups.mean()
    # Filter info for just the job we are interested in
    jobdf = df.set_index(['Model', 'Compression'])
    # Remove redundant info
    return jobdf.unstack()['MAPE']

ff = 'DejaVu Sans'
ff = 'DejaVu Serif'
matplotlib.rc('font', family=ff)

model_names = list(map(lambda m:m.name, models))

colors = ['tab:blue', 'tab:green', 'red', 'tab:orange', 'black']

plt.figure(figsize=(8,8))
results = read_results_all_jobs()
plt.subplot(3,2,1)
#plt.title('KMEANS vs. DBSCAN vs. KMEDEOIDS', fontsize=17)
for j, model_name in enumerate(model_names):
    y = results.loc[model_name][:]
    x = [0,1,2,3,4]
    line = plt.plot(x, y, label=model_name, color=colors[j])
    
    plt.xlabel('Kompressionsschritte', fontsize=15)
    plt.ylabel('MAPE', fontsize=15)
        
    plt.ylim(0, .25)

plt.figlegend(model_names, fontsize=15, loc='center right', 
              bbox_transform=plt.gcf().transFigure)
plt.savefig('dbscan_vs_kmeans_vs_kmedoids.pdf', bbox_inches='tight')
plt.show()
